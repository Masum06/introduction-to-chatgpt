# %% [markdown]
# <a href="https://colab.research.google.com/github/Masum06/introduction-to-chatgpt/blob/main/Shannon's_guessing_game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Modified Shannon's guessing game
#
# https://www.princeton.edu/~wbialek/rome/refs/shannon_51.pdf

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Guess what word comes next!!

# %%
import sys

# %% [markdown]
# ```
# story = "computers ..."
# ```

# %%
#@title
story = "computers will never fully replace humans until they learn to laugh at their boss's joke"

# %%
tokens = story.split()
num_trials = []

# %%
print("Total Number of words: ", len(tokens))
# Out:
# Total Number of words:  15

# %%
print("Type exit() to quit.\n\nFirst word: computers\n\n")

for token in tokens[1:]:
  guess = ""
  i = 0
  while True:
    i += 1
    guess = input().strip().lower()
    if guess == "exit()":
      print("Byee!! 🤗")
      sys.exit(0)
    if guess == token.lower():
      num_trials.append(i)
      print(">>", "Correct!! 😄 Number of trial:", i, "\n")
      break
    else:
      print(">>", "Wrong!! 🥺 Number of trial:", i,  "\n")

# %%
for (i, j) in zip(num_trials, tokens[:len(num_trials)]):
  print(i, j)
